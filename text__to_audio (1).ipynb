# %%
# !pip install gTTS

# %%
from gtts import gTTS
from IPython.display import Audio

# Convert text to speech
rhyme = """The moon climbs high in skies so deep,
While stars around her softly sleep.
She paints the night in silver beams,
And tiptoes through our quiet dreams.

She hides behind the drifting cloud,
Yet shines again, both bold and proud.
She hums a tune the owls all know,
And bathes the world in gentle glow.

No sun could ever match her grace,
With calm and charm upon her face.
She rules the night with silent might—
The queen of dreams, the heart of night."""
tts = gTTS(text=rhyme,lang='en')
tts.save("output.mp3")

# Play audio in Colab
Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
